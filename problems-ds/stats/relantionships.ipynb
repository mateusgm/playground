# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.sparse as sps
import pandas as pd
import scipy as sc

# %matplotlib inline
plt.rcParams['figure.figsize'] = 6, 4

# %%
size = 10000
np.random.seed(seed=10)
X_seed = np.random.normal(0, 1, size)
X0 = X_seed + np.random.normal(0, .1, size)
X1 = X_seed + np.random.normal(0, .1, size)
X2 = X_seed + np.random.normal(0, .1, size)
X = np.array([X0, X1, X2]).T
Y = X0 + X1 + X2

# %%
exp = np.random.exponential(4, size)
log = np.log(exp)

# %%
from scipy import stats

e = np.random.normal(0, .1, size)
x0 = np.append(np.random.normal(0, 1, size/2), np.random.normal(5, 1, size/2))
x1 = np.log(np.abs(x0))
x2 = np.exp(x0)
x3 = x0**2
x4 = x0**3/(1 - np.log(np.abs(x0)))
x5 = np.sqrt(np.abs(x0))

y1 = x1 + X1**2 + X2 + e
y2 = x2 + X1**2 + X2 + e
y3 = x3 + X1**2 + X2 + e
y4 = x4 + X1**2 + X2 + e
y5 = x5 + X1**2 + X2 + e


plt.hist(x0, bins=50) and plt.show()
plt.hist(x1, bins=50) and plt.show()
plt.hist(x2, bins=50) and plt.show()
plt.hist(x3, bins=50) and plt.show()
plt.hist(x4, bins=50) and plt.show()
plt.hist(x5, bins=50) and plt.show()

plt.scatter(x0, y1) and plt.show()
plt.scatter(x0, y2) and plt.show()
plt.scatter(x0, y3) and plt.show()
plt.scatter(x0, y4) and plt.show()
plt.scatter(x0, y5) and plt.show()

plt.scatter(x1, y1) and plt.show()
plt.scatter(x2, y2) and plt.show()
plt.scatter(x3, y3) and plt.show()
plt.scatter(x4, y4) and plt.show()
plt.scatter(x5, y5) and plt.show()

# %%
def reg(name, x,y):
    model = sm.OLS(y, x)
    results = model.fit()
    print name, "==============================\n", results.summary()

reg("x0 : y1", x0, y1)
reg("x1 : y1", x1, y1)
reg("x0 : y2", x0, y2)
reg("x2 : y2", x2, y2)
reg("x0 : y3", x0, y3)
reg("x3 : y3", x3, y3)
reg("x0 : y4", x0, y4)
reg("x4 : y4", x4, y4)
reg("x0 : y5", x0, y5)
reg("x5 : y5", x5, y5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4aed8af3c273> in <module>()
#       5     print name, "==============================\n", results.summary()
#       6
# ----> 7 reg("x0 : y1", x0, y1)
#       8 reg("x1 : y1", x1, y1)
#       9 reg("x0 : y2", x0, y2)
#
# <ipython-input-6-4aed8af3c273> in reg(name, x, y)
#       1
#       2 def reg(name, x,y):
# ----> 3     model = sm.OLS(y, x)
#       4     results = model.fit()
#       5     print name, "==============================\n", results.summary()
#
# NameError: global name 'sm' is not defined

# %%
norm_a = np.random.normal(10, 3, 1000)
norm_b = np.random.normal(200, 20, 1000)
unif_c = np.random.beta(100, 200, 1000)

# %%
def scatter(a,b):
    plt.scatter(a,b)
    plt.show()

scatter(norm_a, unif_c)
scatter(norm_a, 1/norm_b)
scatter(norm_a, np.sqrt(norm_b) + np.random.normal(.01, .02, 1000))
scatter(norm_a, np.log(norm_a))
scatter(norm_a, np.sqrt(norm_b**2.5))
scatter(norm_a, norm_b**(-1))

# %%
plt.hist(np.exp(norm_b**(-4)))
plt.hist(np.log(norm_b**(-4)))
# Out:
# (array([   7.,   32.,  112.,  225.,  297.,  176.,  100.,   37.,   12.,    2.]),
#  array([-22.37221385, -22.10529069, -21.83836753, -21.57144436,
#         -21.3045212 , -21.03759804, -20.77067487, -20.50375171,
#         -20.23682855, -19.96990538, -19.70298222]),
#  <a list of 10 Patch objects>)
